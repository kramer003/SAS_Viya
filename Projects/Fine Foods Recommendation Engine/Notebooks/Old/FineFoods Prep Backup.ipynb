# %% [markdown]
# # Fine Foods - Recommendation Engine
# We will be using food reviews from Amazon to build a recommendation engine using Factorization Machine in SAS VIYA
#
# Factorization Machine (FM) is one of the newest algorithms in the Machine Learning space, and has been developed in SAS. FM is a general prediction algorithm, similar to Support Vector Machines, that can model very sparce data, an area where traditional Machine Learning techniques fail.
#
# this notebook has four parts:
# 1. Load in Data
# 2. SVD to represent text numerically
# 3. Train Recommendation Engine
# 4. Make Recommendation

# %% [markdown]
# ## Load in Data

# %%
from swat import *
#swat.options.cas.print_messages = False

# Connect to the session
cashost='racesx12069.demo.sas.com'
casport=5570
casauth='U:\.authinfo_w12_race'

s = CAS(cashost, casport, authinfo=casauth, caslib="casuser")

#Load Data
f='foods_prepped'
s.loadTable(caslib='DemoData', path=f+'.csv', casout=f);

#Load actionsets
actionsets=['fedSQL', 'autoTune', 'factMac', 'textMining']
[s.builtins.loadactionset(i) for i in actionsets];


#Create shortcuts
food = s.CASTable(f)
target = 'score'
class_inputs = ['helpfulness','productid','time','userid']
# Out:
# NOTE: Cloud Analytic Services made the file foods_prepped.csv available as table FOODS_PREPPED in caslib CASUSER(sasdemo).
# NOTE: Added action set 'fedSQL'.
# NOTE: Added action set 'autoTune'.
# NOTE: Added action set 'factMac'.
# NOTE: Added action set 'textMining'.

# %%
s.dataStep.runCode('''data '''+f+'''; 
                      set '''+f+''';
                      key=_n_; run;''')

print(len(food), "Reviews")
food.head()
# Out:
# 568454 Reviews
# Selected Rows from Table FOODS_PREPPED
#
#   helpfulness   productId  score  \
# 0         2/2  B000HEA964    5.0
# 1         2/2  B000HEA964    5.0
# 2         2/2  B000HEA964    4.0
# 3         2/2  B000HEA964    5.0
# 4         1/1  B000HEA964    5.0
#
#                                         summary  \
# 0                          Dog's Favorite Snack
# 1                         Better Than "Cookies"
# 2                          Good for small dogs.
# 3                                         great
# 4  Cost more than steak, but my dogs love them!
#
#                                                 text          time  \
# 0  These chicken chips are devored daily by my 2 ...  1.212883e+09
# 1  These crunchy treats are irresistable to my Co...  1.208304e+09
# 2  I have two American Eskimo dogs, and so these ...  1.204157e+09
# 3  My little dog loved these. Were first sent to ...  1.176163e+09
# 4  My two Havanese really love these!  They are v...  1.285114e+09
#
#            userId      key
# 0  A2E61OQYIVB55P  67425.0
# 1  A2UCGE4EQZ0P4A  67426.0
# 2  A304WL23L6EDML  67427.0
# 3  A287Z78FJTTT27  67428.0
# 4  A18UVHCREY2RE2  67429.0

# %% [markdown]
# ## Text Mining

# %%
s.loadTable(caslib='DemoData', path='engstop'+'.sas7bdat', casout='engstop');
# Out:
# NOTE: Cloud Analytic Services made the file engstop.sas7bdat available as table ENGSTOP in caslib CASUSER(sasdemo).

# %%
def c_dict(name):
    training_options = dict(name      = name,
                            replace   = True)                           
    return training_options

s.textMining.tmMine(
  documents=f,
  stopList="engstop",
  docId="key",
  copyVars=class_inputs + [target],
  text='text',
  reduce=10,
  entities="STD",
  k=3,
  norm="DOC",
  u=c_dict("svdu"),
  terms=c_dict("terms"),
  parent=c_dict("parent"),
  child=c_dict("child"),
  parseConfig=c_dict("config"),
  docPro=c_dict("docpro"),
  topics=c_dict("topics"),
)
# Out:
# [OutputCasTablesFull]
#
#               casLib    Name Label      Rows  Columns  \
#  0  CASUSER(sasdemo)  config               1       11
#  1  CASUSER(sasdemo)   terms          141740       11
#  2  CASUSER(sasdemo)  parent        15670231        3
#  3  CASUSER(sasdemo)   child        16503075        3
#  4  CASUSER(sasdemo)    svdu           72708        4
#  5  CASUSER(sasdemo)  docpro          568454        9
#  6  CASUSER(sasdemo)  topics               3        3
#
#                                          casTable
#  0  CASTable('config', caslib='CASUSER(sasdemo)')
#  1   CASTable('terms', caslib='CASUSER(sasdemo)')
#  2  CASTable('parent', caslib='CASUSER(sasdemo)')
#  3   CASTable('child', caslib='CASUSER(sasdemo)')
#  4    CASTable('svdu', caslib='CASUSER(sasdemo)')
#  5  CASTable('docpro', caslib='CASUSER(sasdemo)')
#  6  CASTable('topics', caslib='CASUSER(sasdemo)')
#
# + Elapsed: 1.65e+03s, user: 3.55e+03s, sys: 77.4s, mem: 42.5mb

# %%
#s.table.droptable(name=f)
# Out:
# NOTE: Cloud Analytic Services dropped table foods_prepped from caslib CASUSER(sasdemo).
# + Elapsed: 0.0986s, sys: 0.097s, mem: 0.0306mb

# %%
#s.loadactionset('textmining')
s.textMining.tmMine(
  documents=f,
  stopList='engstop',
  docId="key",
  copyVars=class_inputs + [target],
  text='text',
  reduce=10,
  entities="STD",
  k=3,
  norm="DOC",
  docPro="docpro"
)

# %% [markdown]
# ## See structured representation of first 5 documents

# %%
s.CASTable("docpro").fetch(to=5)
# Out:
# [Fetch]
#
#  Selected Rows from Table DOCPRO
#
#        key    _Col1_    _Col2_    _Col3_ helpfulness   productId          time  \
#  0  8408.0  0.793594  0.302304  0.528035         0/0  B00146K7MU  1.288829e+09
#  1  8409.0  0.774742  0.256919  0.577726         4/4  B001ESKSPY  1.294618e+09
#  2  8410.0  0.835524  0.256906  0.485694         2/2  B001ESKSPY  1.308269e+09
#  3  8411.0  0.836214  0.289241  0.465924         6/6  B004749DY4  1.327018e+09
#  4  8412.0  0.795012  0.366726  0.483184         6/7  B004749DY4  1.324426e+09
#
#             userId  score
#  0   AYYACIDP5I4V6    5.0
#  1  A3SQJCRXHOQ8GF    5.0
#  2  A1XUX4HFY8F7YW    5.0
#  3  A216NSW58Q3SCJ    4.0
#  4   ACJT8MUC0LRF0    4.0
#
# + Elapsed: 0.00323s, user: 0.002s, sys: 0.001s, mem: 0.564mb

# %%
s.table.save(caslib='DemoData', name='Foods_prep_text.sashdat', table="docpro")

# %%
s.loadactionset('autotune')

training_options = dict(
                    table     = dict(name = 'docpro'),
                    inputs    = class_inputs, # + ['_Col1_','_Col2_','_Col3_'],
                    nominals  = class_inputs,
                    target    = target,
                    seed      = 123,
                    savestate = dict(name = 'fm_model_short', replace = True))

s.invoke('autotune.tuneFactMac', trainOptions=training_options,
                                           tunerOptions=dict(maxTime=300, validationPartitionFraction=0.1),
                                           tuningParameters=[dict(namePath='nfactors', initValue=2)])

for response in s:
    for k, v in response:
        print(k, v)
# Out:
# NOTE: Added action set 'autotune'.
# NOTE: Autotune is started for 'Factorization Machine' model.
# NOTE: Autotune option SEARCHMETHOD='GA'.
# NOTE: Autotune option MAXEVALS=50.
# NOTE: Autotune option MAXTIME=300 (sec.).
# NOTE: Autotune objective is 'Root Average Squared Error'.
# NOTE: Autotune number of parallel evaluations is set to 4, each using 0 worker nodes.
# NOTE: The INITVALUE '2' of tuning parameter NFACTORS is not included in the VALUELIST for this parameter.
# NOTE: The initial point will not be used to seed the tuning process.
# NOTE: The seed for random partition/fold generation is 123.
#          Iteration       Evals     Best Objective        Time
#                  0           1             1.1292       20.63
#                  1           9             1.1292      300.00
# NOTE: Autotune process reached maximum tuning time.
# NOTE: Using SEED=123.
# NOTE: Beginning data reading and levelization...
# NOTE: Data reading and levelization complete.
# NOTE: Beginning optimization of the factorization machine model...
# NOTE: >>> Progress: completed iteration 1
# NOTE: >>> Progress: completed iteration 2
# NOTE: >>> Progress: completed iteration 3
# NOTE: >>> Progress: completed iteration 4
# NOTE: >>> Progress: completed iteration 5
# NOTE: >>> Progress: completed iteration 6
# NOTE: >>> Progress: completed iteration 7
# NOTE: >>> Progress: completed iteration 8
# NOTE: >>> Progress: completed iteration 9
# NOTE: >>> Progress: completed iteration 10
# NOTE: >>> Progress: completed iteration 11
# NOTE: >>> Progress: completed iteration 12
# NOTE: >>> Progress: completed iteration 13
# NOTE: >>> Progress: completed iteration 14
# NOTE: >>> Progress: completed iteration 15
# NOTE: >>> Progress: completed iteration 16
# NOTE: >>> Progress: completed iteration 17
# NOTE: >>> Progress: completed iteration 18
# NOTE: >>> Progress: completed iteration 19
# NOTE: >>> Progress: completed iteration 20
# NOTE: >>> Progress: completed iteration 21
# NOTE: >>> Progress: completed iteration 22
# NOTE: >>> Progress: completed iteration 23
# NOTE: >>> Progress: completed iteration 24
# NOTE: >>> Progress: completed iteration 25
# NOTE: >>> Progress: completed iteration 26
# NOTE: >>> Progress: completed iteration 27
# NOTE: >>> Progress: completed iteration 28
# NOTE: >>> Progress: completed iteration 29
# NOTE: >>> Progress: completed iteration 30
# NOTE: Optimization complete.
# ModelInfo Model Information
#
#           Description    Value
# 0  Maximum Iterations   30.000
# 1   Number of Factors    2.000
# 2       Learning Step    0.001
# 3                Seed  123.000
# NObs Number of Observations
#
#                           Type         N
# 0  Number of Observations Read  511491.0
# 1  Number of Observations Used  511491.0
# DescStatsInt Interval Variables
#
#   Variable      Mean    StdDev
# 0    score  4.181896  1.311297
# DescStatsNom Nominal Variables
#
#       Variable  NumLevels
# 0  helpfulness     1520.0
# 1    productId    71107.0
# 2         time     3152.0
# 3       userId   237943.0
# OptIterHistory     Progress  Objective      Loss
# 0        1.0   1.858601  1.858601
# 1        2.0   1.541945  1.541945
# 2        3.0   1.400505  1.400505
# 3        4.0   1.319949  1.319949
# 4        5.0   1.267470  1.267470
# 5        6.0   1.230294  1.230294
# 6        7.0   1.201846  1.201846
# 7        8.0   1.178695  1.178695
# 8        9.0   1.159419  1.159419
# 9       10.0   1.142681  1.142681
# 10      11.0   1.127777  1.127777
# 11      12.0   1.114139  1.114139
# 12      13.0   1.101664  1.101664
# 13      14.0   1.089800  1.089800
# 14      15.0   1.078384  1.078384
# 15      16.0   1.067224  1.067224
# 16      17.0   1.056341  1.056341
# 17      18.0   1.045691  1.045691
# 18      19.0   1.035248  1.035248
# 19      20.0   1.025083  1.025083
# 20      21.0   1.015198  1.015198
# 21      22.0   1.005763  1.005763
# 22      23.0   0.996798  0.996798
# 23      24.0   0.987821  0.987821
# 24      25.0   0.979358  0.979358
# 25      26.0   0.971302  0.971302
# 26      27.0   0.963497  0.963497
# 27      28.0   0.956016  0.956016
# 28      29.0   0.948870  0.948870
# 29      30.0   0.941833  0.941833
# FinalLoss Final Exact Loss
#
#   Criterion     Value
# 0       MSE  0.936658
# 1      RMSE  0.967811
# TargetInfo   LEVNAME  LEVINDEX  VARNAME
# 0                 0  P_score
# NOTE: Wrote 18285186 bytes to the savestate file fm_model_short.
# FitStat Fit Statistics for _AUTOTUNE_DEFAULT_SCORE_TABLE_
#
#       NOBS      ASE      DIV     RASE       MAE      RMAE      MSLE     RMSLE
# 0  36829.0  1.27394  36829.0  1.12869  0.795007  0.891632  0.124632  0.353032
# TunerInfo Tuner Information
#
#                          Parameter                       Value
# 0                       Model Type       Factorization Machine
# 1         Tuner Objective Function  Root Average Squared Error
# 2                    Search Method                          GA
# 3              Maximum Evaluations                          50
# 4                  Population Size                          10
# 5               Maximum Iterations                           5
# 6   Maximum Tuning Time in Seconds                         300
# 7                  Validation Type            Single Partition
# 8    Validation Partition Fraction                        0.10
# 9                        Log Level                           2
# 10                            Seed                         123
# TunerResults Tuner Results
#
#    Evaluation  NFACTORS  MAXITER  LEARNSTEP   RootASE
# 0           0         2       30   0.001000  1.129171
# 1           3         5       30   0.000100  1.488559
# 2           6        20       10   0.001000  1.890018
# 3           1         5       50   1.000000  4.159689
# 4           2        30       70   0.000001  4.281352
# EvaluationHistory Tuner Evaluation History
#
#    Evaluation  NFACTORS  MAXITER  LEARNSTEP   RootASE
# 0           0         2       30   0.001000  1.129171
# 1           1         5       50   1.000000  4.159689
# 2           2        30       70   0.000001  4.281352
# 3           3         5       30   0.000100  1.488559
# 4           4        20       10   0.001000  1.890018
# BestConfiguration Best Configuration
#
#                       Parameter  Value
# 0                    Evaluation      0
# 1             Number of Factors      2
# 2  Maximum Number of Iterations     30
# 3            Learning Step Size  0.001
# 4    Root Average Squared Error   1.13
# NOTE: Autotune time is 323.17 seconds.
# TunerSummary Tuner Summary
#
#                                           Parameter       Value
# 0             Initial Configuration Objective Value    1.129171
# 1                Best Configuration Objective Value    1.129171
# 2               Worst Configuration Objective Value    4.281352
# 3  Initial Configuration Evaluation Time in Seconds   20.630923
# 4     Best Configuration Evaluation Time in Seconds  282.275260
# 5                 Number of Improved Configurations    1.000000
# 6                Number of Evaluated Configurations    9.000000
# 7                      Total Tuning Time in Seconds  323.169906
# 8                           Parallel Tuning Speedup    3.628693
# TunerTiming Tuner Task Timing
#
#                           Task     Time_sec  Time_percent
# 0               Model Training  1147.159102     97.823347
# 1                Model Scoring    19.426375      1.656573
# 2  Total Objective Evaluations  1166.593832     99.480633
# 3                        Tuner     6.090535      0.519367
# 4               Total CPU Time  1172.684367    100.000000

# %%
s.loadactionset('autotune')

training_options = dict(
                    table     = dict(name = f),
                    inputs    = class_inputs,
                    nominals  = class_inputs,
                    target    = target,
                    seed      = 123,
                    savestate = dict(name = 'fm_model_short', replace = True))

s.invoke('autotune.tuneFactMac', trainOptions=training_options,
                                           tunerOptions=dict(maxTime=300, validationPartitionFraction=0.1),
                                           tuningParameters=[dict(namePath='nfactors', initValue=2)])

for response in s:
    for k, v in response:
        print(k, v)
# Out:
# NOTE: Added action set 'autotune'.
# NOTE: Autotune is started for 'Factorization Machine' model.
# NOTE: Autotune option SEARCHMETHOD='GA'.
# NOTE: Autotune option MAXEVALS=50.
# NOTE: Autotune option MAXTIME=300 (sec.).
# NOTE: Autotune objective is 'Root Average Squared Error'.
# NOTE: Autotune number of parallel evaluations is set to 4, each using 0 worker nodes.
# NOTE: The INITVALUE '2' of tuning parameter NFACTORS is not included in the VALUELIST for this parameter.
# NOTE: The initial point will not be used to seed the tuning process.
# NOTE: The seed for random partition/fold generation is 123.
#          Iteration       Evals     Best Objective        Time
#                  0           1             1.1184       25.50
#                  1           9             1.1184      300.00
# NOTE: Autotune process reached maximum tuning time.
# NOTE: Using SEED=123.
# NOTE: Beginning data reading and levelization...
# NOTE: Data reading and levelization complete.
# NOTE: Beginning optimization of the factorization machine model...
# NOTE: >>> Progress: completed iteration 1
# NOTE: >>> Progress: completed iteration 2
# NOTE: >>> Progress: completed iteration 3
# NOTE: >>> Progress: completed iteration 4
# NOTE: >>> Progress: completed iteration 5
# NOTE: >>> Progress: completed iteration 6
# NOTE: >>> Progress: completed iteration 7
# NOTE: >>> Progress: completed iteration 8
# NOTE: >>> Progress: completed iteration 9
# NOTE: >>> Progress: completed iteration 10
# NOTE: >>> Progress: completed iteration 11
# NOTE: >>> Progress: completed iteration 12
# NOTE: >>> Progress: completed iteration 13
# NOTE: >>> Progress: completed iteration 14
# NOTE: >>> Progress: completed iteration 15
# NOTE: >>> Progress: completed iteration 16
# NOTE: >>> Progress: completed iteration 17
# NOTE: >>> Progress: completed iteration 18
# NOTE: >>> Progress: completed iteration 19
# NOTE: >>> Progress: completed iteration 20
# NOTE: >>> Progress: completed iteration 21
# NOTE: >>> Progress: completed iteration 22
# NOTE: >>> Progress: completed iteration 23
# NOTE: >>> Progress: completed iteration 24
# NOTE: >>> Progress: completed iteration 25
# NOTE: >>> Progress: completed iteration 26
# NOTE: >>> Progress: completed iteration 27
# NOTE: >>> Progress: completed iteration 28
# NOTE: >>> Progress: completed iteration 29
# NOTE: >>> Progress: completed iteration 30
# NOTE: Optimization complete.
# ModelInfo Model Information
#
#           Description    Value
# 0  Maximum Iterations   30.000
# 1   Number of Factors    2.000
# 2       Learning Step    0.001
# 3                Seed  123.000
# NObs Number of Observations
#
#                           Type         N
# 0  Number of Observations Read  511510.0
# 1  Number of Observations Used  511510.0
# DescStatsInt Interval Variables
#
#   Variable      Mean    StdDev
# 0    score  4.182984  1.310837
# DescStatsNom Nominal Variables
#
#       Variable  NumLevels
# 0  helpfulness     1509.0
# 1    productId    71120.0
# 2         time     3140.0
# 3       userId   238260.0
# OptIterHistory     Progress  Objective      Loss
# 0        1.0   1.867806  1.867806
# 1        2.0   1.546502  1.546502
# 2        3.0   1.403672  1.403672
# 3        4.0   1.323149  1.323149
# 4        5.0   1.270978  1.270978
# 5        6.0   1.233518  1.233518
# 6        7.0   1.204940  1.204940
# 7        8.0   1.181700  1.181700
# 8        9.0   1.162331  1.162331
# 9       10.0   1.145925  1.145925
# 10      11.0   1.131223  1.131223
# 11      12.0   1.117647  1.117647
# 12      13.0   1.105343  1.105343
# 13      14.0   1.093680  1.093680
# 14      15.0   1.082473  1.082473
# 15      16.0   1.071547  1.071547
# 16      17.0   1.060797  1.060797
# 17      18.0   1.050041  1.050041
# 18      19.0   1.039869  1.039869
# 19      20.0   1.029629  1.029629
# 20      21.0   1.019903  1.019903
# 21      22.0   1.010115  1.010115
# 22      23.0   1.000977  1.000977
# 23      24.0   0.991886  0.991886
# 24      25.0   0.983389  0.983389
# 25      26.0   0.974921  0.974921
# 26      27.0   0.967078  0.967078
# 27      28.0   0.959427  0.959427
# 28      29.0   0.952016  0.952016
# 29      30.0   0.944796  0.944796
# FinalLoss Final Exact Loss
#
#   Criterion     Value
# 0       MSE  0.939581
# 1      RMSE  0.969320
# TargetInfo   LEVNAME  LEVINDEX  VARNAME
# 0                 0  P_score
# NOTE: Wrote 18304128 bytes to the savestate file fm_model_short.
# FitStat Fit Statistics for _AUTOTUNE_DEFAULT_SCORE_TABLE_
#
#       NOBS       ASE      DIV      RASE       MAE      RMAE      MSLE  \
# 0  37108.0  1.246222  37108.0  1.116343  0.787095  0.887183  0.122991
#
#       RMSLE
# 0  0.350701
# TunerInfo Tuner Information
#
#                          Parameter                       Value
# 0                       Model Type       Factorization Machine
# 1         Tuner Objective Function  Root Average Squared Error
# 2                    Search Method                          GA
# 3              Maximum Evaluations                          50
# 4                  Population Size                          10
# 5               Maximum Iterations                           5
# 6   Maximum Tuning Time in Seconds                         300
# 7                  Validation Type            Single Partition
# 8    Validation Partition Fraction                        0.10
# 9                        Log Level                           2
# 10                            Seed                         123
# TunerResults Tuner Results
#
#    Evaluation  NFACTORS  MAXITER  LEARNSTEP   RootASE
# 0           0         2       30   0.001000  1.118429
# 1           3         5       30   0.000100  1.476649
# 2           6        20       10   0.001000  1.874352
# 3           1         5       50   1.000000  4.167351
# 4           2        30       70   0.000001  4.293601
# EvaluationHistory Tuner Evaluation History
#
#    Evaluation  NFACTORS  MAXITER  LEARNSTEP   RootASE
# 0           0         2       30   0.001000  1.118429
# 1           1         5       50   1.000000  4.167351
# 2           2        30       70   0.000001  4.293601
# 3           3         5       30   0.000100  1.476649
# 4           4        20       10   0.001000  1.874352
# BestConfiguration Best Configuration
#
#                       Parameter  Value
# 0                    Evaluation      0
# 1             Number of Factors      2
# 2  Maximum Number of Iterations     30
# 3            Learning Step Size  0.001
# 4    Root Average Squared Error   1.12
# NOTE: Autotune time is 325.72 seconds.
# TunerSummary Tuner Summary
#
#                                           Parameter       Value
# 0             Initial Configuration Objective Value    1.118429
# 1                Best Configuration Objective Value    1.118429
# 2               Worst Configuration Objective Value    4.293601
# 3  Initial Configuration Evaluation Time in Seconds   25.496149
# 4     Best Configuration Evaluation Time in Seconds  277.277315
# 5                 Number of Improved Configurations    1.000000
# 6                Number of Evaluated Configurations    9.000000
# 7                      Total Tuning Time in Seconds  325.718555
# 8                           Parallel Tuning Speedup    3.562257
# TunerTiming Tuner Task Timing
#
#                           Task     Time_sec  Time_percent
# 0               Model Training  1129.310271     97.329724
# 1                Model Scoring    24.642563      2.123822
# 2  Total Objective Evaluations  1153.960258     99.454185
# 3                        Tuner     6.333052      0.545815
# 4               Total CPU Time  1160.293310    100.000000

# %%
s.loadactionset('factmac')

# Build the factorization machine
r = s.factmac.factmac(
  table     = dict(name = f),
  inputs    = class_inputs,
  nominals  = class_inputs,
  target    = target,
  maxIter   = 50,
  nFactors  = 20,
  learnStep = 0.01,
  seed      = 12345,
  savestate = dict(name = 'fm_model', replace = True)
)

r['FinalLoss']
# Out:
# NOTE: Added action set 'factmac'.
# NOTE: Using SEED=12345.
# NOTE: Beginning data reading and levelization...
# NOTE: Data reading and levelization complete.
# NOTE: Beginning optimization of the factorization machine model...
# NOTE: >>> Progress: completed iteration 1
# NOTE: >>> Progress: completed iteration 2
# NOTE: >>> Progress: completed iteration 3
# NOTE: >>> Progress: completed iteration 4
# NOTE: >>> Progress: completed iteration 5
# NOTE: >>> Progress: completed iteration 6
# NOTE: >>> Progress: completed iteration 7
# NOTE: >>> Progress: completed iteration 8
# NOTE: >>> Progress: completed iteration 9
# NOTE: >>> Progress: completed iteration 10
# NOTE: >>> Progress: completed iteration 11
# NOTE: >>> Progress: completed iteration 12
# NOTE: >>> Progress: completed iteration 13
# NOTE: >>> Progress: completed iteration 14
# NOTE: >>> Progress: completed iteration 15
# NOTE: >>> Progress: completed iteration 16
# NOTE: >>> Progress: completed iteration 17
# NOTE: >>> Progress: completed iteration 18
# NOTE: >>> Progress: completed iteration 19
# NOTE: >>> Progress: completed iteration 20
# NOTE: >>> Progress: completed iteration 21
# NOTE: >>> Progress: completed iteration 22
# NOTE: >>> Progress: completed iteration 23
# NOTE: >>> Progress: completed iteration 24
# NOTE: >>> Progress: completed iteration 25
# NOTE: >>> Progress: completed iteration 26
# NOTE: >>> Progress: completed iteration 27
# NOTE: >>> Progress: completed iteration 28
# NOTE: >>> Progress: completed iteration 29
# NOTE: >>> Progress: completed iteration 30
# NOTE: >>> Progress: completed iteration 31
# NOTE: >>> Progress: completed iteration 32
# NOTE: >>> Progress: completed iteration 33
# NOTE: >>> Progress: completed iteration 34
# NOTE: >>> Progress: completed iteration 35
# NOTE: >>> Progress: completed iteration 36
# NOTE: >>> Progress: completed iteration 37
# NOTE: >>> Progress: completed iteration 38
# NOTE: >>> Progress: completed iteration 39
# NOTE: >>> Progress: completed iteration 40
# NOTE: >>> Progress: completed iteration 41
# NOTE: >>> Progress: completed iteration 42
# NOTE: >>> Progress: completed iteration 43
# NOTE: >>> Progress: completed iteration 44
# NOTE: >>> Progress: completed iteration 45
# NOTE: >>> Progress: completed iteration 46
# NOTE: >>> Progress: completed iteration 47
# NOTE: >>> Progress: completed iteration 48
# NOTE: >>> Progress: completed iteration 49
# NOTE: >>> Progress: completed iteration 50
# NOTE: Optimization complete.
# NOTE: Wrote 67798977 bytes to the savestate file fm_model.
# Final Exact Loss
#
#   Criterion     Value
# 0       MSE  0.038322
# 1      RMSE  0.195761
